# %%
from pybaseball import statcast, standings, playerid_lookup, pitching_stats, batting_stats, statcast_pitcher, schedule_and_record
schedule_and_record(2023, 'ATL')
# Out:
# http://www.baseball-reference.com/teams/ATL/2023-schedule-scores.shtml
#                   Date   Tm Home_Away  Opp   W/L    R    RA   Inn     W-L  \
# 1     Thursday, Mar 30  ATL         @  WSN     W  7.0   2.0   9.0     1-0
# 2      Saturday, Apr 1  ATL         @  WSN     W  7.0   1.0   9.0     2-0
# 3        Sunday, Apr 2  ATL         @  WSN     L  1.0   4.0   9.0     2-1
# 4        Monday, Apr 3  ATL         @  STL     W  8.0   4.0   9.0     3-1
# 5       Tuesday, Apr 4  ATL         @  STL     W  4.0   1.0   9.0     4-1
# ..                 ...  ...       ...  ...   ...  ...   ...   ...     ...
# 158  Wednesday, Sep 27  ATL      Home  CHC  W-wo  6.0   5.0  10.0  102-56
# 159   Thursday, Sep 28  ATL      Home  CHC     W  5.0   3.0   9.0  103-56
# 160     Friday, Sep 29  ATL      Home  WSN     L  6.0  10.0   9.0  103-57
# 161   Saturday, Sep 30  ATL      Home  WSN     W  5.0   3.0   9.0  104-57
# 162      Sunday, Oct 1  ATL      Home  WSN     L  9.0  10.0   9.0  104-58
#
# ...
